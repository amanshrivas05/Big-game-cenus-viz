# %% [markdown]
# # Feature engineering

# %%
# import library
import pandas as pd
import numpy as np

# %%
big_game = pd.read_excel("C://Users//AMAN//Downloads//biggame.xlsx")

# %%
big_game
# Out:
#            Player Name Player Jersey Number Player Position  Player Age  \
# 0       Devin McCourty                  #32            S/FS          30
# 1       Danny Amendola                  #80        PR/WR/KR          32
# 2     Johnson Bademosi                  #29     CB/SPTM/RCB          27
# 3          Chris Hogan                  #15              WR          29
# 4        James Develin                  #46           RB/FB          29
# ..                 ...                  ...             ...         ...
# 113         Nick Foles                   #9              QB          28
# 114        Will Beatty                  #66           T/LOT          32
# 115       Donnie Jones                   #8           P/HLD          37
# 116  Kamu Grugier-Hill                  #54     LB/SPTM/RLB          23
# 117      Isaac Seumalo                  #73           G/ROG          24
#
#      Player Weight (lbs.) Years Played Player Birthplace (city, town, etc.)  \
# ...

# %%
big_game.head(5)
# Out:
#         Player Name Player Jersey Number Player Position  Player Age  \
# 0    Devin McCourty                  #32            S/FS          30
# 1    Danny Amendola                  #80        PR/WR/KR          32
# 2  Johnson Bademosi                  #29     CB/SPTM/RCB          27
# 3       Chris Hogan                  #15              WR          29
# 4     James Develin                  #46           RB/FB          29
#
#    Player Weight (lbs.) Years Played Player Birthplace (city, town, etc.)  \
# 0                   195            8                               Nanuet
# 1                   190            9                        The Woodlands
# 2                   206            6                        Silver Spring
# 3                   210            5                              Wyckoff
# 4                   255            5                        Gilbertsville
#
#   Player Birth State    Player Birthplace (Combo) Player College  ...  \
# ...

# %%
big_game.tail(5)
# Out:
#            Player Name Player Jersey Number Player Position  Player Age  \
# 113         Nick Foles                   #9              QB          28
# 114        Will Beatty                  #66           T/LOT          32
# 115       Donnie Jones                   #8           P/HLD          37
# 116  Kamu Grugier-Hill                  #54     LB/SPTM/RLB          23
# 117      Isaac Seumalo                  #73           G/ROG          24
#
#      Player Weight (lbs.) Years Played Player Birthplace (city, town, etc.)  \
# 113                   243            6                               Austin
# 114                   319            9                                 York
# 115                   221           14                          Baton Rouge
# 116                   220            2                             Honolulu
# 117                   303            2                             Honolulu
#
#     Player Birth State Player Birthplace (Combo)    Player College  ...  \
# ...

# %%
big_game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 24 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Player Name                                               118 non-null    object
#  1   Player Jersey Number                                      118 non-null    object
#  2   Player Position                                           118 non-null    object
#  3   Player Age                                                118 non-null    int64
#  4   Player Weight (lbs.)                                      118 non-null    int64
#  5   Years Played                                              118 non-null    object
#  6   Player Birthplace (city, town, etc.)                      118 non-null    object
#  7   Player Birth State                                        118 non-null    object
# ...

# %%
big_game["Player Age"].mean()
# Out:
# 26.720338983050848

# %%
big_game["Player Weight (lbs.)"].mean()
# Out:
# 243.88135593220338

# %%
big_game.describe()
# Out:
#        Player Age  Player Weight (lbs.)  State GEO ID  \
# count  118.000000            118.000000    118.000000
# mean    26.720339            243.881356     28.330508
# std      3.653556             45.959322     17.071521
# min     21.000000            167.000000      1.000000
# 25%     24.000000            205.000000     12.000000
# 50%     26.000000            238.000000     31.000000
# 75%     29.000000            274.000000     40.500000
# max     40.000000            350.000000     75.000000
#
#        Latitude (player birthplace)  Longitude (player birthplace)  \
# count                    118.000000                     118.000000
# mean                      35.566567                     -92.820792
# std                        7.449830                      20.707252
# min                      -14.252294                    -170.713450
# 25%                       32.416135                     -97.764743
# 50%                       36.164258                     -86.614908
# ...

# %% [markdown]
# # Form Age of player we can entersapt that

# %% [markdown]
# #### min age of player is 21 years
#
# #### and max age of player is 40 years
#
# #### avg age of a player is 26 years
#
# #### 75% of player belong to age group between 24-29

# %% [markdown]
# # Form Player Weight (lbs.) of player we can entersapt that

# %% [markdown]
# #### min weight of player is 167 lbs
#
# #### max wegiht of player is 350 lbs
#
# #### avg weight of player is 243.88lbs
#
# #### 75% of player have weight between 167-274 lbs

# %%
#  what are unique values in year player
big_game['Years Played'].unique()
# Out:
# array([8, 9, 6, 5, 4, 2, 3, 1, 10, 15, 12, 11, 'R', 7, 18, 13, 14],
#       dtype=object)

# %% [markdown]
# ## the most experianced player has 18 year of experiance and atleast one year experiance

# %%
big_game['Player Team'].describe(include=['O'])
# Out:
# count             118
# unique              2
# top       New England
# freq               60
# Name: Player Team, dtype: object

# %%
big_game['Player Team'].unique()
# Out:
# array(['New England', 'Philadelphia'], dtype=object)

# %% [markdown]
# ## Two Teams from which player from New England', 'Philadelphia

# %%
# what are different playing position
big_game['Player Position'].unique()
# Out:
# array(['S/FS', 'PR/WR/KR', 'CB/SPTM/RCB', 'WR', 'RB/FB', 'T/ROT', 'S/SS',
#        'CB/LCB', 'WR/PR', 'RB', 'RB/KR', 'LB/RLB', 'KR/WR', 'LB/RDE',
#        'C/ROG', 'CB/RCB', 'K/KFG/KKO', 'DT/RDT', 'DE/RDE', 'S/FS/SPTM',
#        'LB/MLB', 'P/HLD', 'QB', 'DT', 'LB/LS', 'C', 'LB/LLB', 'TE',
#        'DT/LDE', 'DE', 'G/C', 'DE/LDE', 'DE/LDT', 'T/LOG', 'G/LOG',
#        'T/LOT', 'DT/LDT', 'RB/SPTM', 'S/SS/SPTM', 'KR/RB', 'RB/KR/PR',
#        'LB/LLB/SPTM', 'C/LOG', 'G/ROG', 'LB/SPTM/RLB'], dtype=object)

# %% [markdown]
# # We look into the  2017 population data of states

# %%
state=pd.read_excel("C://Users//AMAN//Downloads//All states Census 2017 Population Estimates.xlsx")

# %%
state.head()
# Out:
#          GEOID  GEOID2 Geography Name  April 1, 2010 - Census  \
# 0  0400000US01       1        Alabama                 4779736
# 1  0400000US02       2         Alaska                  710231
# 2  0400000US04       4        Arizona                 6392017
# 3  0400000US05       5       Arkansas                 2915918
# 4  0400000US06       6     California                37253956
#
#    April 1, 2010 - Estimates Base  Population Estimate (as of July 1) - 2010  \
# 0                         4780135                                    4785579
# 1                          710249                                     714015
# 2                         6392309                                    6407002
# 3                         2916031                                    2921737
# 4                        37254518                                   37327690
#
#    Population Estimate (as of July 1) - 2011  \
# 0                                    4798649
# ...

# %%
state.tail()
# Out:
#           GEOID  GEOID2 Geography Name  April 1, 2010 - Census  \
# 47  0400000US53      53     Washington                 6724540
# 48  0400000US54      54  West Virginia                 1852994
# 49  0400000US55      55      Wisconsin                 5686986
# 50  0400000US56      56        Wyoming                  563626
# 51  0400000US72      72    Puerto Rico                 3725789
#
#     April 1, 2010 - Estimates Base  Population Estimate (as of July 1) - 2010  \
# 47                         6724545                                    6741386
# 48                         1853006                                    1854315
# 49                         5687288                                    5690403
# 50                          563767                                     564376
# 51                         3726157                                    3721525
#
#     Population Estimate (as of July 1) - 2011  \
# 47                                    6819155
# ...

# %%
state.info
# Out:
# <bound method DataFrame.info of           GEOID  GEOID2        Geography Name  April 1, 2010 - Census  \
# 0   0400000US01       1               Alabama                 4779736
# 1   0400000US02       2                Alaska                  710231
# 2   0400000US04       4               Arizona                 6392017
# 3   0400000US05       5              Arkansas                 2915918
# 4   0400000US06       6            California                37253956
# 5   0400000US08       8              Colorado                 5029196
# 6   0400000US09       9           Connecticut                 3574097
# 7   0400000US10      10              Delaware                  897934
# 8   0400000US11      11  District of Columbia                  601723
# 9   0400000US12      12               Florida                18801310
# 10  0400000US13      13               Georgia                 9687653
# 11  0400000US15      15                Hawaii                 1360301
# ...

# %%
state.describe()
# Out:
#           GEOID2  April 1, 2010 - Census  April 1, 2010 - Estimates Base  \
# count  52.000000            5.200000e+01                    5.200000e+01
# mean   29.788462            6.009064e+06                    6.009313e+06
# std    16.774557            6.764460e+06                    6.764684e+06
# min     1.000000            5.636260e+05                    5.637670e+05
# 25%    16.750000            1.761651e+06                    1.761658e+06
# 50%    29.500000            4.085220e+06                    4.085206e+06
# 75%    42.500000            6.591857e+06                    6.591992e+06
# max    72.000000            3.725396e+07                    3.725452e+07
#
#        Population Estimate (as of July 1) - 2010  \
# count                               5.200000e+01
# mean                                6.020384e+06
# std                                 6.779468e+06
# min                                 5.643760e+05
# 25%                                 1.765195e+06
# ...

# %%
state['Geography Name'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Puerto Rico'],
#       dtype=object)

# %%
state['GEOID2'].mean()
# Out:
# 29.78846153846154

# %%
state['GEOID2'].max()
# Out:
# 72

# %%
state['GEOID2'].median()
# Out:
# 29.5

# %% [markdown]
# #  we look into the 2016 population data of cities

# %%
cities=pd.read_excel("C://Users//AMAN//Downloads//All Places Census 2016 Population Estimates.xlsx")

# %%
cities.head()
# Out:
#       Geographic ID  GEOID 2 Geography, full name (City, State)  \
# 0  1620000US0100124   100124            Abbeville city, Alabama
# 1  1620000US0100460   100460           Adamsville city, Alabama
# 2  1620000US0100484   100484              Addison town, Alabama
# 3  1620000US0100676   100676                Akron town, Alabama
# 4  1620000US0100820   100820            Alabaster city, Alabama
#
#   April 1, 2010 - Census  April 1, 2010 - Estimates Base  \
# 0                   2688                            2688
# 1                   4522                            4522
# 2                    758                             756
# 3                    356                             356
# 4                  30352                           31066
#
#    Population Estimate (as of July 1) - 2010  \
# 0                                       2683
# 1                                       4517
# 2                                        754
# 3                                        355
# ...

# %%
cities.tail()
# Out:
#           Geographic ID  GEOID 2 Geography, full name (City, State)  \
# 19505  1620000US5681300  5681300            Wamsutter town, Wyoming
# 19506  1620000US5683040  5683040            Wheatland town, Wyoming
# 19507  1620000US5684925  5684925              Worland city, Wyoming
# 19508  1620000US5685015  5685015               Wright town, Wyoming
# 19509  1620000US5686665  5686665                Yoder town, Wyoming
#
#       April 1, 2010 - Census  April 1, 2010 - Estimates Base  \
# 19505                    451                             451
# 19506                   3627                            3627
# 19507                   5487                            5487
# 19508                   1807                            1807
# 19509                    151                             151
#
#        Population Estimate (as of July 1) - 2010  \
# 19505                                        450
# 19506                                       3629
# ...

# %%
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19510 entries, 0 to 19509
# Data columns (total 12 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Geographic ID                              19510 non-null  object
#  1   GEOID 2                                    19510 non-null  int64
#  2   Geography, full name (City, State)         19510 non-null  object
#  3   April 1, 2010 - Census                     19510 non-null  object
#  4   April 1, 2010 - Estimates Base             19510 non-null  int64
#  5   Population Estimate (as of July 1) - 2010  19510 non-null  int64
#  6   Population Estimate (as of July 1) - 2011  19510 non-null  int64
#  7   Population Estimate (as of July 1) - 2012  19510 non-null  int64
#  8   Population Estimate (as of July 1) - 2013  19510 non-null  int64
#  9   Population Estimate (as of July 1) - 2014  19510 non-null  int64
# ...

# %%
cities.describe()
# Out:
#             GEOID 2  April 1, 2010 - Estimates Base  \
# count  1.951000e+04                    1.951000e+04
# mean   3.008271e+06                    9.909960e+03
# std    1.461650e+06                    8.012455e+04
# min    1.001240e+05                    0.000000e+00
# 25%    1.857141e+06                    3.690000e+02
# 50%    2.940709e+06                    1.147000e+03
# 75%    4.202612e+06                    4.603250e+03
# max    5.686665e+06                    8.174962e+06
#
#        Population Estimate (as of July 1) - 2010  \
# count                               1.951000e+04
# mean                                9.930210e+03
# std                                 8.028673e+04
# min                                 0.000000e+00
# 25%                                 3.690000e+02
# 50%                                 1.148000e+03
# 75%                                 4.606000e+03
# max                                 8.192026e+06
#
# ...

# %%
cities['GEOID 2'].mean()
# Out:
# 3008271.2834443874

# %%
cities['GEOID 2'].median()
# Out:
# 2940709.0

# %%
cities['GEOID 2'].max()
# Out:
# 5686665

# %% [markdown]
# # END
